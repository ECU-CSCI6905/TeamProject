# %%
import dogCatCnn
# Out:
# C:\Users\Quan.Phan\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Found 5161 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.
# Epoch 1/25
#    2/8000 [..............................] - ETA: 53:57 - loss: 0.7937 - acc: 0.5000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-ce96f3cd36a0> in <module>()
# ----> 1 import dogCatCnn
#
# ~\Downloads\ECU-CSCI6905-Deep-Learning\workspace\TeamProject\src\cnn\dogCatCnn.py in <module>()
#      70                                      epochs = 25,
#      71                                      validation_data = testing_set,
# ...

# %%
import dogCatCnn
# Out:
# Found 5161 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.
# Epoch 1/25
#  570/8000 [=>............................] - ETA: 31:59 - loss: 0.5839 - acc: 0.6915
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-ce96f3cd36a0> in <module>()
# ----> 1 import dogCatCnn
#
# ~\Downloads\ECU-CSCI6905-Deep-Learning\workspace\TeamProject\src\cnn\dogCatCnn.py in <module>()
#      70                                      epochs = 25,
#      71                                      validation_data = testing_set,
# ---> 72                                      validation_steps = 2000)
#      73
#      74
#
# ~\anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
# ...

# %%
import dogCatCnn
# Out:
# Found 5161 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.
# Epoch 1/6
# 8000/8000 [==============================] - 2370s 296ms/step - loss: 0.3413 - acc: 0.8443 - val_loss: 0.6417 - val_acc: 0.7766
# Epoch 2/6
# 7999/8000 [============================>.] - ETA: 0s - loss: 0.1265 - acc: 0.9505
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ce96f3cd36a0> in <module>()
# ----> 1 import dogCatCnn
#
# ~\Downloads\ECU-CSCI6905-Deep-Learning\workspace\TeamProject\src\cnn\dogCatCnn.py in <module>()
#      70                                      epochs = 6,
#      71                                      validation_data = testing_set,
# ---> 72                                      validation_steps = 2000)
#      73
#      74
#
# ~\anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
# ...

# %%
import dogCatCnn
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\Quan.Phan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-4-ce96f3cd36a0>", line 1, in <module>
#     import dogCatCnn
#
#   File "C:\Users\Quan.Phan\Downloads\ECU-CSCI6905-Deep-Learning\workspace\TeamProject\src\cnn\dogCatCnn.py", line 99
#     print "Enter a file name to test in the neural net or enter q to quit: "
#                                                                            ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(int "Enter a file name to test in the neural net or enter q to quit: ")?

# %%
import dogCatCnn
# Out:
# Found 5161 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.
# Epoch 1/2
# 800/800 [==============================] - 228s 285ms/step - loss: 0.5417 - acc: 0.7180 - val_loss: 0.5897 - val_acc: 0.6945
# Epoch 2/2
# 800/800 [==============================] - 229s 286ms/step - loss: 0.4435 - acc: 0.7924 - val_loss: 0.5514 - val_acc: 0.7470
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# Enter a file name to test in the neural net or enter q to quit:
# > d001
# Bad file name. Try again.
# Enter a file name to test in the neural net or enter q to quit:
# > d001.jpg
# Bad file name. Try again.
# Enter a file name to test in the neural net or enter q to quit:
# > q
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# ...

# %%
import dogCatCnn
# Out:
# Found 5161 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.
# Epoch 1/25
# 200/200 [==============================] - 61s 303ms/step - loss: 0.6145 - acc: 0.6626 - val_loss: 0.7248 - val_acc: 0.5500
# Epoch 2/25
# 200/200 [==============================] - 59s 295ms/step - loss: 0.5591 - acc: 0.7083 - val_loss: 0.6748 - val_acc: 0.5919
# Epoch 3/25
# 200/200 [==============================] - 59s 295ms/step - loss: 0.5249 - acc: 0.7275 - val_loss: 0.5984 - val_acc: 0.6694
# Epoch 4/25
# 200/200 [==============================] - 60s 301ms/step - loss: 0.4911 - acc: 0.7581 - val_loss: 0.6287 - val_acc: 0.6931
# Epoch 5/25
# 200/200 [==============================] - 60s 298ms/step - loss: 0.4756 - acc: 0.7688 - val_loss: 0.6273 - val_acc: 0.6856
# Epoch 6/25
# 200/200 [==============================] - 59s 295ms/step - loss: 0.4376 - acc: 0.7973 - val_loss: 0.4934 - val_acc: 0.7619
# Epoch 7/25
# ...
