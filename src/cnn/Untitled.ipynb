# %%
import dogCatCnn
# Out:
# C:\Users\Quan.Phan\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Found 5161 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.
# Epoch 1/5
#  27/400 [=>............................] - ETA: 1:42 - loss: 0.6800 - acc: 0.6516
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-ce96f3cd36a0> in <module>()
# ----> 1 import dogCatCnn
#
# ~\Downloads\ECU-CSCI6905-Deep-Learning\workspace\TeamProject\src\cnn\dogCatCnn.py in <module>()
#      70                                      epochs = 5,
#      71                                      validation_data = testing_set,
# ...

# %%
import dogCatCnn
# Out:
# Found 5161 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.
# Epoch 1/5
# 400/400 [==============================] - 116s 290ms/step - loss: 0.5847 - acc: 0.6849 - val_loss: 0.6376 - val_acc: 0.6567
# Epoch 2/5
# 400/400 [==============================] - 118s 295ms/step - loss: 0.5250 - acc: 0.7317 - val_loss: 0.6058 - val_acc: 0.7049
# Epoch 3/5
# 400/400 [==============================] - 126s 315ms/step - loss: 0.4781 - acc: 0.7678 - val_loss: 1.0033 - val_acc: 0.5676
# Epoch 4/5
# 400/400 [==============================] - 129s 323ms/step - loss: 0.4507 - acc: 0.7847 - val_loss: 0.5671 - val_acc: 0.7241
# Epoch 5/5
# 400/400 [==============================] - 123s 308ms/step - loss: 0.4239 - acc: 0.8029 - val_loss: 0.6512 - val_acc: 0.7159
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
